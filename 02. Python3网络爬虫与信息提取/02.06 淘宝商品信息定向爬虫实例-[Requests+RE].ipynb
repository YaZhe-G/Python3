# %%
#淘宝商品信息定向爬虫实例
import requests
import re

def getHTMLText(url):
    try:
        r = requests.get(url,timeout = 30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""
    
def parsePage(ilt,html):
    try:
        plt = re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)
        tlt = re.findall(r'\"raw_title\"\:\".*?\"',html)  #最小匹配
        for i in range(len(plt)):
            price = eval(plt[i].split(':')[1])
            title = eval(tlt[i].split(':')[1])
            ilt.append([price,title])
    except:
        print("")
    
def printGoodsList(ilt):
    tplt = "{:^4}\t{:8}\t{:16}\t"  #{a:^b}  a表示索引，b表示字符串的宽度，^表示左对齐。
    print(tplt.format("序号","价格","商品名称"))
    count = 0
    for g in ilt:
        count = count + 1
        print(tplt.format(count,g[0],g[1]))
    
def main():
    goods = '书包'
    depth = 2
    start_url = 'https://s.taobao.com/search?q=' + goods
    inforList = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44*i)
            html = getHTMLText(url)
            parsePage(inforList,html)
        except:
            continue
    printGoodsList(inforList)
    
if __name__ == '__main__':
    main()
# Out:
#  序号 	价格      	商品名称
#  1  	118.00  	韩国书包小学生男孩12岁儿童书包女1-6年级
#  2  	69.00   	迪士尼书包小学生男女1-3-4-6年级米奇减负背包儿童书包8-10-12岁
#  3  	119.00  	韩国kk树书包小学生男1-3-4-6年级儿童书包女6-12周岁双肩包护脊
#  4  	43.00   	帆布双肩包女学院风韩版潮学生背包休闲初中学生书包外置USB充电
#  5  	279.00  	佑一良品日本潮牌双肩包男包背包 铆钉迷彩休闲书包旅行包电脑包
#  6  	79.80   	韩版初中生书包女帆布校园双肩包男旅行背包高中学生书包学院风潮
#  7  	29.90   	天天特价书包女韩版原宿ulzzang高中学生潮流帆布校园背包双肩包
#  8  	56.90   	2017新款儿童双肩包百搭可爱男女童韩版时尚书包迷你背包小包包皮
#  9  	25.00   	撤店甩货零点女包斜挎包单肩包帆布包学院风初高中大学生书包
#  10 	14.80   	韩国简约手工新品布包手提单肩帆布袋文艺学生书包购物袋子女
#  11 	26.80   	包包2017便宜新款韩版双肩包女包潮高初中大学生书包简约男士背包
#  12 	60.80   	书包女韩日版原宿ulzzang 高中学生校园百搭简约背包 潮 双肩包女
#  13 	38.00   	旅行包女卡通双肩包三用印花小人休闲双背包迷你学生书包女单肩包
#  14 	52.00   	文博士书包 小学生大容量男女生双肩儿童减负书包1-3-6年级 粉红
#  15 	145.00  	户外儿童旅游背包旅行男童轻便双肩包补习书包小学生3年级1补课包
#  16 	49.00   	女孩儿童双肩包女韩版潮时尚公主旅游背包9-12-14岁小学生书包皮
#  17 	39.00   	2016新款儿童韩版帆布幼儿园宝宝书包小学生男女双肩休闲可爱背包
#  18 	18.80   	限量特惠】潮流双肩背包休闲旅行户外大容量书包男女式商务电脑包
#  19 	79.00   	尼龙双肩包韩版潮男士书包休闲女背包牛津布防水帆布大容量旅行包
